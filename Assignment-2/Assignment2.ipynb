# %% [markdown]
# # Context-sensitive Spelling Correction
#
# The goal of the assignment is to implement context-sensitive spelling correction. The input of the code will be a set of text lines and the output will be the same lines with spelling mistakes fixed.
#
# Submit the solution of the assignment to Moodle as a link to your GitHub repository containing this notebook.
#
# Useful links:
# - [Norvig's solution](https://norvig.com/spell-correct.html)
# - [Norvig's dataset](https://norvig.com/big.txt)
# - [Ngrams data](https://www.ngrams.info/download_coca.asp)
#
# Grading:
# - 60 points - Implement spelling correction
# - 20 points - Justify your decisions
# - 20 points - Evaluate on a test set

# %% [markdown]
# ## Implement context-sensitive spelling correction
#
# Your task is to implement context-sensitive spelling corrector using N-gram language model. The idea is to compute conditional probabilities of possible correction options. For example, the phrase "dking sport" should be fixed as "doing sport" not "dying sport", while "dking species" -- as "dying species".
#
# The best way to start is to analyze [Norvig's solution](https://norvig.com/spell-correct.html) and [N-gram Language Models](https://web.stanford.edu/~jurafsky/slp3/3.pdf).
#
# You may also want to implement:
# - spell-checking for a concrete language - Russian, Tatar, etc. - any one you know, such that the solution accounts for language specifics,
# - some recent (or not very recent) paper on this topic,
# - solution which takes into account keyboard layout and associated misspellings,
# - efficiency improvement to make the solution faster,
# - any other idea of yours to improve the Norvig’s solution.
#
# IMPORTANT:
# Your project should not be a mere code copy-paste from somewhere. You must provide:
# - Your implementation
# - Analysis of why the implemented approach is suggested
# - Improvements of the original approach that you have chosen to implement

# %% [markdown]
# ### 1. Implementing the Norvig's SpellChecker as baseline

# %%
import re
from collections import Counter

from typing import List


class NorvigSpellChecker:
    """Norvig's Spell Checker"""

    def __init__(self, path_to_vocab: str = None):
        self.WORDS = None
        self.total_n = None

        if path_to_vocab:
            self.vocab_init(path_to_vocab)

    def vocab_init(self, path_to_vocab: str):
        self.WORDS = Counter(self.words(open(path_to_vocab).read()))
        self.total_n = sum(self.WORDS.values())

    def word_prob(self, word: str, total_n: int = None):
        """Probability of `word`."""

        if total_n is None:
            total_n = self.total_n

        return self.WORDS[word] / total_n

    def correction(self, word: str):
        """Most probable spelling correction for word."""
        return max(self.candidates(word), key=self.word_prob)

    def text_correction(self, text: str):
        """Most probable spelling correction for text."""
        return re.sub(r'\w+', lambda m: self.correction(m.group(0)), text)

    def candidates(self, word: str):
        """Generate possible spelling corrections for word."""
        return self.known(self.edits1(word)) or self.known([word]) or self.known(self.edits2(word)) or [word]

    def known(self, words: List[str]):
        """The subset of `words` that appear in the dictionary of WORDS."""
        return set(w for w in words if w in self.WORDS)

    @staticmethod
    def words(text: str):
        return re.findall(r'\w+', text.lower())

    @staticmethod
    def edits1(word: str):
        """All edits that are one edit away from `word`."""
        letters = 'abcdefghijklmnopqrstuvwxyz'

        splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
        deletes = [L + R[1:] for L, R in splits if R]
        transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1]
        replaces = [L + c + R[1:] for L, R in splits if R for c in letters]
        inserts = [L + c + R for L, R in splits for c in letters]

        return set(deletes + transposes + replaces + inserts)

    @staticmethod
    def edits2(word: str):
        """All edits that are two edits away from `word`."""
        return (e2 for e1 in NorvigSpellChecker.edits1(word) for e2 in NorvigSpellChecker.edits1(e1))

# %% [markdown]
# ### 2. Implementing the Context Sensitive Spell Checker

# %%
WORDS_FREQ = dict()
EDITS_FREQ = dict()


def add_edit(edits, L, R):
    """Add an edit to the list of edits."""
    return edits + [R + '|' + L]


def generate_edits(head, tail, edit_distance, edits, result, possible_prefixes,
                   alphabet='abcdefghijklmnopqrstuvwxyz'):
    """Generate edits for the given head and tail."""

    C = head + tail
    if C in WORDS_FREQ:
        e = '+'.join(edits)
        result[C] = (max(result.get(C, ('', 0))[0], e,
                         key=(lambda x: EDITS_FREQ.get(x, 1) / sum(EDITS_FREQ.values()))), edit_distance)

    if edit_distance <= 0:
        return

    extensions = [head + c for c in alphabet if head + c in possible_prefixes]
    p = head[-1] if head else '<'

    # Insertion
    for h in extensions:
        generate_edits(h, tail, edit_distance - 1, add_edit(edits, p + h[-1], p), result, possible_prefixes)

    if not tail:
        return

    # Deletion
    generate_edits(head, tail[1:], edit_distance - 1, add_edit(edits, p, p + tail[0]), result, possible_prefixes)

    # Match or Replacement
    for h in extensions:
        if h[-1] == tail[0]:
            generate_edits(h, tail[1:], edit_distance, edits, result, possible_prefixes)
        else:
            generate_edits(h, tail[1:], edit_distance - 1, add_edit(edits, h[-1], tail[0]), result, possible_prefixes)

    # Transpose
    if len(tail) >= 2 and tail[0] != tail[1] and head + tail[1] in possible_prefixes:
        generate_edits(head + tail[1], tail[0] + tail[2:], edit_distance - 1,
                       add_edit(edits, tail[1] + tail[0], tail[0:2]), result,
                       possible_prefixes)


class CSSpellChecker:
    """
    Context Sensitive Spell Checker
    
    The class implements context-sensitive spell checker using N-gram language model.
    It extends the NorvigSpellChecker class.
    """

    def __init__(self, path_to_words_freq: str, path_to_edits_freq: str,
                 path_to_bigrams: str, path_to_fivegrams: str,
                 word_sep: str = ' ', edit_sep: str = ' ',
                 max_edit_distance: int = 2, freq_threshold: int = 1):
        super().__init__()

        self.bigrams_freq = self.load_ngram_data(path_to_bigrams)
        self.first_word_frequencies = self.calculate_first_word_frequencies()

        self.fivegrams_freq = self.load_ngram_data(path_to_fivegrams)

        self.words_freq = self.load_freqs(path_to_words_freq, sep=word_sep)
        self.words_freq = Counter({word: freq for word, freq in self.words_freq.items() if freq > freq_threshold})

        self.edits_freq = self.load_freqs(path_to_edits_freq, sep=edit_sep)

        self.possible_prefixes = self.compute_possible_prefixes()
        self.alphabet = 'abcdefghijklmnopqrstuvwxyz'
        self.max_edit_distance = max_edit_distance

        global WORDS_FREQ, EDITS_FREQ
        WORDS_FREQ = self.words_freq
        EDITS_FREQ = self.edits_freq
        self.WORDS = self.words_freq

    @staticmethod
    def load_freqs(path_to_freqs: str, sep: str = ' '):
        """
        Load frequencies from the file.
        :param sep: separator between word/edit and its frequency
        :param path_to_freqs: path to the file with frequencies
        :return: Counter with frequencies
        """

        with open(path_to_freqs, 'r', encoding='cp1251') as f:
            return Counter(
                {
                    pair.split(sep)[0]: int(pair.split(sep)[1])
                    for pair in f.readlines()
                }
            )

    @staticmethod
    def load_ngram_data(path: str):
        with open(path, 'r', encoding='cp1251') as f:
            return Counter(
                {
                    tuple(line.split()[1:]): int(line.split()[0])
                    for line in f.readlines()
                }
            )

    def compute_possible_prefixes(self):
        """
        Compute possible prefixes for the words in the vocabulary.
        :return: set of possible prefixes
        """

        return set(
            word[:i]
            for word in self.words_freq
            for i in range(len(word) + 1)
        )

    def correction(self, word: str):
        """Method for compatibility with Norvig's SpellChecker"""

        word = word.lower()

        return self.word_correction(word)

    def word_correction(self, word: str):
        """Most probable spelling correction for word."""

        all_candidates = self.candidates(word)

        if not all_candidates:
            return word

        word = max(all_candidates,
                   key=lambda word: self.word_prob(word) *
                                    self.edit_prob(all_candidates[word][0]) *
                                    (0.001 + all_candidates[word][1])
                   )

        return word

    def text_correction(self, text: str):
        """Most probable spelling correction for text."""

        # Tokenize the input text into words
        tokens = re.compile(r"(\w[\w']*\w|\w)").findall(text.lower().strip())
        
        # Correct the first word in the text
        corrected_text = [self.word_correction(tokens[0])]
        
        # Iterate over the rest of the words in the text
        for token in tokens[1:]:
            # Create a bigram with the last corrected word and the current word
            bigram = (corrected_text[-1], token)
        
            # If the bigram exists in the bigram frequency dataset, append the current word to the corrected text
            if bigram in self.bigrams_freq:
                corrected_text.append(token)
                continue
        
            # If the current word is a single character, append it to the corrected text
            if len(bigram[1]) == 1:
                corrected_text.append(token)
                continue
        
            # Generate possible corrections for the current word
            word_candidates = self.candidates(token)
        
            # If there are no candidates, append the current word to the corrected text
            if not word_candidates:
                corrected_text.append(token)
                continue
        
            # Create bigram candidates with the last corrected word and the word candidates
            bigram_candidates = [
                (bigram[0], word)
                for word in word_candidates
            ]
        
            # Select the bigram with the highest probability
            bigram = max(bigram_candidates, key=lambda bigram: self.bigram_prob(bigram))
        
            # Append the corrected word to the corrected text
            corrected_text.append(bigram[1])

        return ' '.join(corrected_text)

    def candidates(self, word: str):
        """Generate possible spelling corrections for word."""

        result = dict()

        generate_edits(head='', tail=word,
                       edit_distance=self.max_edit_distance, edits=[],
                       result=result, possible_prefixes=self.possible_prefixes)

        return result

    def word_prob(self, word: str):
        """Probability of `word`."""

        if word in self.words_freq:
            return self.words_freq[word] / sum(self.words_freq.values())

        # Default probability for unknown words
        return 1 / sum(self.words_freq.values())

    def edit_prob(self, edit: str):
        """Probability of `edit`."""
        avg_spell_error_freq = 0.05

        if not edit:
            return 1 - avg_spell_error_freq

        prob = avg_spell_error_freq
        for e in edit.split('+'):
            prob *= self.edits_freq.get(e, 1) / sum(self.edits_freq.values())

        return prob

    def bigram_prob(self, bigram: str):
        """Probability of `bigram`."""

        if bigram in self.bigrams_freq:
            return self.bigrams_freq[bigram] / (self.first_word_frequencies[bigram[0]] + 1)

        return 1 / (self.first_word_frequencies[bigram[0]] + 1)

    def calculate_first_word_frequencies(self):
        """Calculate frequencies of the first words in the bigrams."""

        first_word_frequencies = Counter()

        for bigram in self.bigrams_freq:
            first_word_frequencies[bigram[0]] += self.bigrams_freq[bigram]

        return first_word_frequencies

# %% [markdown]
# ## Minimal testing while developing

# %%
spellchecker = CSSpellChecker(
    path_to_words_freq='data/internet/top_300k_words_freq.txt',
    word_sep='\t',

    path_to_edits_freq='data/internet/single_edits_freq.txt',
    edit_sep='\t',

    path_to_bigrams='data/coco/bigrams.txt',
    path_to_fivegrams='data/coco/fivegrams.txt',

    freq_threshold=700000
)

# %%
spellchecker.correction('helgo')
# Out:
# 'hello'

# %%
spellchecker.text_correction("Helgo, my nama is cool. I al a studenn.")
# Out:
# 'hello to name is cool i was a student'

# %% [markdown]
# ## Justify your decisions
#
# Write down justificaitons for your implementation choices. For example, these choices could be:
# - Which ngram dataset to use
# - Which weights to assign for edit1, edit2 or absent words probabilities
# - Beam search parameters
# - etc.

# %% [markdown]
# Justifications on implementation choices:
# 1. **N-gram dataset**: I used the COCA dataset for bigrams and fivegrams. The dataset is large and contains a lot of text data, which is important for the language model. The bigrams and fivegrams are used to calculate the probability of the word given the previous word. This is important for the context-sensitive spell correction.
# 2. **Word Frequencies**: I used the top 300k words from the internet. The words with the frequency less than 700k were removed. This is done to reduce the size of the vocabulary and speed up the computations. The words with the frequency less than 700k are considered rare and are not likely to be used in the context-sensitive spell correction. The dataset was composed of Google Web Trillion Word Corpus.
# 3. **Edit Frequencies**: I used the single edits frequencies from the internet. Those frequencies help me to calculate the probability of concrete sequence of edits.
# 4. **Edit Distance**: I used the edit distance of 2. This is a common choice for the spell correction tasks. The edit distance of 2 allows to correct the words with two typos.
# 5. **Bigram Probability**: The bigram probability is calculated as the frequency of the bigram divided by the frequency of the first word in the bigram. If the bigram is found in the dataset - it counts as correct.

# %% [markdown]
# ## Evaluate on a test set
#
# Your task is to generate a test set and evaluate your work. You may vary the noise probability to generate different datasets with varying compexity. Compare your solution to the Norvig's corrector, and report the accuracies.

# %%
norvig_sc = NorvigSpellChecker(path_to_vocab='data/norvig/big.txt')

# %%
context_sensitive_sc = CSSpellChecker(
    path_to_words_freq='data/internet/top_300k_words_freq.txt',
    word_sep='\t',

    path_to_edits_freq='data/internet/single_edits_freq.txt',
    edit_sep='\t',

    path_to_bigrams='data/coco/bigrams.txt',
    path_to_fivegrams='data/coco/fivegrams.txt',

    freq_threshold=700000
)

# %% [markdown]
# ### Tests written by hand

# %%
tests = {
    "Helgo, my nama is cool. I al a studenn.": "Hello, my name is cool. I am a student.",
    "Thiss sentennce hass a lot of missspelled worts.": "This sentence has a lot of misspelled worts."
}

# %%
for test, expected in tests.items():
    print("#" * 50)
    print()

    print(f"Test: {test}")
    print(f"Expected: {expected}")

    print("-" * 50)

    print(f"Norvig: {norvig_sc.text_correction(test)}")
    print(f"Context-sensitive: {context_sensitive_sc.text_correction(test)}")

    print()
# Out:
# ##################################################
#
# Test: Helgo, my nama is cool. I al a studenn.
# Expected: Hello, my name is cool. I am a student.
# --------------------------------------------------
# Norvig: hello, by name in fool. a a a student.
# Context-sensitive: hello to name is cool i was a student
#
# ##################################################
#
# Test: Thiss sentennce hass a lot of missspelled worts.
# Expected: This sentence has a lot of misspelled worts.
# --------------------------------------------------
# Norvig: hiss sentence has a not of misspelled words.
# Context-sensitive: his sentence was a lot of missspelled forts

# %% [markdown]
# ### Generating test set

# %%
test_text = ("No one is perfect and we do not claim to find every error in your text. "
             "That is just not possible with a machine-only check. If others claim they can do this automatically, it is just not correct."
             " The last resort is always a human (and even this person may fail from time to time). "
             "Nevertheless our online spellchecker will help you find most errors and will also make suggestions for grammatical improvements.")

# %%
test_text_cleared = ' '.join(re.compile(r"(\w[\w']*\w|\w)").findall(test_text.lower().strip()))

# %%
import random
import string


def misspell_word(word, p=0.1):
    misspelled_word = ""

    for i, c in enumerate(word):
        if random.random() < p:
            misspelled_word += random.choice(list(set(string.ascii_lowercase) - {c}) + [''])
        else:
            misspelled_word += c

    return misspelled_word


def misspell_text(text, word_noise=0.1, text_noise=0.1):
    tokens = re.compile(r"(\w[\w']*\w|\w)").findall(text.lower().strip())

    return ' '.join([misspell_word(token, word_noise) if random.random() < text_noise else token for token in tokens])

# %%
text_noises = [0.1, 0.3, 0.5, 0.7, 0.9]
word_noises = [0.1, 0.2, 0.3, 0.4]


def test_text_correction(text, word_noises, text_noises, verbose=False):
    if verbose:
        print("Initial clear text:", text, sep='\n')

    total_tests = len(text_noises) * len(word_noises)
    test_num = 0
    norvig_avg_acc = 0
    context_sensitive_avg_acc = 0
    for text_noise in text_noises:
        for word_noise in word_noises:
            print("#" * 50)
            print("Test number:", test_num + 1, f"out of {total_tests}")
            test_num += 1
            print()

            print("Text noise:", text_noise)
            print("Word noise:", word_noise)

            print("-" * 50)

            text_noised = misspell_text(text, word_noise, text_noise)

            norvig_correction = norvig_sc.text_correction(text_noised)
            context_sensitive_correction = context_sensitive_sc.text_correction(text_noised)

            norvig_acc = sum([1 for a, b in zip(norvig_correction.split(), test_text_cleared.split()) if a == b]) / len(
                test_text_cleared.split())
            context_sensitive_acc = sum(
                [1 for a, b in zip(context_sensitive_correction.split(), test_text_cleared.split()) if a == b]) / len(
                test_text_cleared.split())

            norvig_avg_acc += norvig_acc
            context_sensitive_avg_acc += context_sensitive_acc

            if verbose:
                print(f"Test:", text_noised, sep='\n')

                print("-" * 50)

                print(f"Norvig:", norvig_correction, sep='\n')
                print()
                print(f"Context-sensitive:", context_sensitive_correction, sep='\n')
                
                print()

            print("Norvig accuracy:", norvig_acc)
            print("Context-sensitive accuracy:", context_sensitive_acc)

            print()

    norvig_avg_acc /= total_tests
    context_sensitive_avg_acc /= total_tests

    print("#" * 50)
    print("Average accuracies:")
    print("Norvig:", norvig_avg_acc)
    print("Context-sensitive:", context_sensitive_avg_acc)

# %%
test_text_correction(test_text_cleared, word_noises, text_noises, verbose=True)
# Out:
# Initial clear text:
# no one is perfect and we do not claim to find every error in your text that is just not possible with a machine only check if others claim they can do this automatically it is just not correct the last resort is always a human and even this person may fail from time to time nevertheless our online spellchecker will help you find most errors and will also make suggestions for grammatical improvements
# ##################################################
# Test number: 1 out of 20
#
# Text noise: 0.1
# Word noise: 0.1
# --------------------------------------------------
# Test:
# no one is perfect and we do not claim to find every error in your text that is just not possible with a machine only check if others claim they can do this autozaticalsy it is just not correct the last resort is always a human and even this person may fail from time to time nevertheless our online spellchecker will help you find most errors and will also make suggestions for grammatical improvements
# --------------------------------------------------
# Norvig:
# to on in perfect and he to not claim to mind very terror in you next that in must not possible with a machine only cheek of other claim the an to his automatically in in must not correct the last report in always a human and even his person may fall from time to time nevertheless or online spellchecker will held you mind must error and will also made suggestion for grammatical improvement
#
# Context-sensitive:
# no one is perfect and we do not claim to find every error in your text that is just not possible with a machine on deck of others claim they can do this automatically be is just not correct the last resort is always a human and even this person may fail for time to time nevertheless our online spellchecker will help you find most errors and will also make suggestions for grammatical improvements
#
# Norvig accuracy: 0.5405405405405406
# Context-sensitive accuracy: 0.9324324324324325
#
# ##################################################
# Test number: 2 out of 20
#
# Text noise: 0.1
# Word noise: 0.2
# --------------------------------------------------
# Test:
# no one is perfect and we do not claim to find eykry error in your text that is just not possible with a machine only check if others claim they can do this automatically it is just not correct the last resort is always a human and even thi person may lhdl from time to time nevertheless our onlcne spellchecker wils help you find most errors and will also make suggestions for grammatical improvements
# --------------------------------------------------
# Norvig:
# to on in perfect and he to not claim to mind every terror in you next that in must not possible with a machine only cheek of other claim the an to his automatically in in must not correct the last report in always a human and even the person may ll from time to time nevertheless or online spellchecker will held you mind must error and will also made suggestion for grammatical improvement
#
# Context-sensitive:
# no one is perfect and we do not claim to find every error in your text that is just not possible with a machine on deck of others claim they can do this automatically be is just not correct the last resort is always a human and even the person may hdl from time to time nevertheless our online spellchecker boils help you find most errors and will also make suggestions for grammatical improvements
#
# Norvig accuracy: 0.5540540540540541
# Context-sensitive accuracy: 0.9054054054054054
#
# ##################################################
# Test number: 3 out of 20
#
# Text noise: 0.1
# Word noise: 0.3
# --------------------------------------------------
# Test:
# no one is perfect and we so noh claim to find every error in your text that is just not pdssible wlah a machine only check if others claim twea can do this automytically it is just not correct the last resort is always a human and even this person may fail from time to time nevertheless our online spellchecker will help ynu find most errors and will aiso make suggestions for grammatical improvements
# --------------------------------------------------
# Norvig:
# to on in perfect and he to not claim to mind very terror in you next that in must not possible was a machine only cheek of other claim tea an to his automatically in in must not correct the last report in always a human and even his person may fall from time to time nevertheless or online spellchecker will held you mind must error and will also made suggestion for grammatical improvement
#
# Context-sensitive:
# no one is perfect and we so you claim to find every error in your text that is just not possible with a machine on deck of others claim the can do this automatically be is just not correct the last resort is always a human and even this person may fail for time to time nevertheless our online spellchecker will help you find most errors and will also make suggestions for grammatical improvements
#
# Norvig accuracy: 0.527027027027027
# Context-sensitive accuracy: 0.8918918918918919
#
# ##################################################
# Test number: 4 out of 20
#
# Text noise: 0.1
# Word noise: 0.4
# --------------------------------------------------
# Test:
# no one is perfect and we do not claim to find every error in your text that is just not possible with a machine only check if others claim they can do this aiwomatiballt it ms just not correct the last resort is always a human and even this person may fail from time to time nevertheless our online spellchecker will help you find most errors and wfnl also make suggestions for grammatical ivpoovyxbnts
# --------------------------------------------------
# Norvig:
# to on in perfect and he to not claim to mind very terror in you next that in must not possible with a machine only cheek of other claim the an to his aiwomatiballt in is must not correct the last report in always a human and even his person may fall from time to time nevertheless or online spellchecker will held you mind must error and will also made suggestion for grammatical ivpoovyxbnts
#
# Context-sensitive:
# no one is perfect and we do not claim to find every error in your text that is just not possible with a machine on deck of others claim they can do this aiwomatiballt it was just not correct the last resort is always a human and even this person may fail for time to time nevertheless our online spellchecker will help you find most errors and will also make suggestions for grammatical ivpoovyxbnts
#
# Norvig accuracy: 0.5405405405405406
# Context-sensitive accuracy: 0.9054054054054054
#
# ##################################################
# Test number: 5 out of 20
#
# Text noise: 0.3
# Word noise: 0.1
# --------------------------------------------------
# Test:
# no ona is perfect and we do not claim to find every error ln your qext thvt is just not possible with a machine only check if others claim ttey can do this automatically it is just not cosrect the last resogt is always a human and even this person may fail from time to time nevertheless our online spellchecker will heqp you find most errors and will also make suggestions for grammatical imirtvements
# --------------------------------------------------
# Norvig:
# to on in perfect and he to not claim to mind very terror in you next that in must not possible with a machine only cheek of other claim they an to his automatically in in must not correct the last resort in always a human and even his person may fall from time to time nevertheless or online spellchecker will help you mind must error and will also made suggestion for grammatical improvements
#
# Context-sensitive:
# no one is perfect and we do not claim to find every error in your best that is just not possible with a machine on deck of others claim the can do this automatically be is just not correct the last resort is always a human and even this person may fail for time to time nevertheless our online spellchecker will help you find most errors and will also make suggestions for grammatical improvements
#
# Norvig accuracy: 0.5945945945945946
# Context-sensitive accuracy: 0.9054054054054054
#
# ##################################################
# Test number: 6 out of 20
#
# Text noise: 0.3
# Word noise: 0.2
# --------------------------------------------------
# Test:
# no ne is perfect and we di not claim to find every error in your text that is jubf not possible with a machonh only check if others claim they oan do this automatically it is just not correct the last resort is alwayq a human fne eien this person mae fqil from time to time nevltthewesh oud online spellchecker wqll help you find most errors and wiwl also make suggestions nod grammatical improvements
# --------------------------------------------------
# Norvig:
# to he in perfect and he i not claim to mind very terror in you next that in just not possible with a machine only cheek of other claim the on to his automatically in in must not correct the last report in always a human one even his person may fail from time to time nevltthewesh out online spellchecker will held you mind must error and will also made suggestion not grammatical improvement
#
# Context-sensitive:
# no one is perfect and we do not claim to find every error in your text that is just not possible with a machine on deck of others claim they had a this automatically be is just not correct the last resort is always a human and then this person has full from time to time nevltthewesh aloud online spellchecker dwell help you find most errors and with also make suggestions for grammatical improvements
#
# Norvig accuracy: 0.527027027027027
# Context-sensitive accuracy: 0.8243243243243243
#
# ##################################################
# Test number: 7 out of 20
#
# Text noise: 0.3
# Word noise: 0.3
# --------------------------------------------------
# Test:
# no oxd is eofect and we do not claim to find every error in your text wtat ro kust not possible einh a machine only check if others claim they can do tebs automatically it is just not correct the lgsm resowl ns always a human and even this persoz may fail fros timb to time nevertheless cur onjine spellchecker will help you find most errors and will alsf make suggestions for grammatpgfl imeyovemants
# --------------------------------------------------
# Norvig:
# to old in effect and he to not claim to mind very terror in you next what to must not possible ein a machine only cheek of other claim the an to tens automatically in in must not correct the last resort is always a human and even his person may fall from time to time nevertheless our online spellchecker will held you mind must error and will also made suggestion for grammatpgfl imeyovemants
#
# Context-sensitive:
# no one is perfect and we do not claim to find every error in your text that he just not possible in a machine on deck of others claim they can do this automatically be is just not correct the last resort to always a human and even this period may fail for him to time nevertheless cur nine spellchecker will help you find most errors and will also make suggestions for grammatpgfl imeyovemants
#
# Norvig accuracy: 0.527027027027027
# Context-sensitive accuracy: 0.8108108108108109
#
# ##################################################
# Test number: 8 out of 20
#
# Text noise: 0.3
# Word noise: 0.4
# --------------------------------------------------
# Test:
# nw oqd is perfect and we do not claim to find every error in your text tjat is just not possible with a machine xnmy check if gtheps claim they can d this automatically it is just not correct the last resort is ooways a human and even this person may fwil qtom hime to tiph nevfrtheless our online segsqcmeckjp will help you eicd most errors and will afsj make suggestions for grammatical improvements
# --------------------------------------------------
# Norvig:
# no old in perfect and he to not claim to mind very terror in you next that in must not possible with a machine my cheek of others claim the an a his automatically in in must not correct the last report in always a human and even his person may fail atom him to tips nevertheless or online segsqcmeckjp will held you did must error and will as made suggestion for grammatical improvement
#
# Context-sensitive:
# n word is perfect and we do not claim to find every error in your text that is just not possible with a machine my check if others claim they can d this automatically be is just not correct the last resort is always a human and even this person may feel to have to time nevertheless our online segsqcmeckjp will help you did most errors and will also make suggestions for grammatical improvements
#
# Norvig accuracy: 0.5
# Context-sensitive accuracy: 0.8648648648648649
#
# ##################################################
# Test number: 9 out of 20
#
# Text noise: 0.5
# Word noise: 0.1
# --------------------------------------------------
# Test:
# no one ie perfect and we do not claim to find enery error in your text rhat is just not possible with a machine only check if others claim they can do this automatically gm is just not correct the last resort is always a human and even this person may fail from time to time nevertheless our oncine cpellchecker will help you fivd mwst errors and will also make suggestions for grammatical improvements
# --------------------------------------------------
# Norvig:
# to on in perfect and he to not claim to mind every terror in you next that in must not possible with a machine only cheek of other claim the an to his automatically go in must not correct the last report in always a human and even his person may fall from time to time nevertheless or online cpellchecker will held you find must error and will also made suggestion for grammatical improvement
#
# Context-sensitive:
# no one of perfect and we do not claim to find very error in your text that is just not possible with a machine on deck of others claim they can do this automatically be is just not correct the last resort is always a human and even this person may fail for time to time nevertheless our online cpellchecker will help you did last errors and will also make suggestions for grammatical improvements
#
# Norvig accuracy: 0.5540540540540541
# Context-sensitive accuracy: 0.8648648648648649
#
# ##################################################
# Test number: 10 out of 20
#
# Text noise: 0.5
# Word noise: 0.2
# --------------------------------------------------
# Test:
# wu one is perfect dnt we do not claim to fhnd every eroog in your text that ds just not possible with a machine only check if otherm claim they can do this automatically it is just not correct the last resort is klwyls a human and even this person may fail from tlsw to time nevertheless our online spellchecker will help you find most triors uld aill also make suigestions for grammatical itpvovementt
# --------------------------------------------------
# Norvig:
# we on in perfect ant he to not claim to find very room in you next that is must not possible with a machine only cheek of other claim the an to his automatically in in must not correct the last report in klwyls a human and even his person may fall from also to time nevertheless or online spellchecker will held you mind must troops old all also made suggestions for grammatical itpvovementt
#
# Context-sensitive:
# w e b perfect and we do not claim to find every room in your text that he just not possible with a machine on deck of them climb the can do this automatically be is just not correct the last resort is klwyls a human and even this person may fail for law to time nevertheless our online spellchecker will help you find most trips and all also make suggestions for grammatical itpvovementt
#
# Norvig accuracy: 0.5135135135135135
# Context-sensitive accuracy: 0.7567567567567568
#
# ##################################################
# Test number: 11 out of 20
#
# Text noise: 0.5
# Word noise: 0.3
# --------------------------------------------------
# Test:
# no one is peofwda acd we do not flaii tz find eosry error in ybur text that is just not possible with a machine ihly chelk if otfnbi claim they can do this automatically it is juet not coreect the last resort is aywayy a human asd even mbzs person man fail from time to time bevecchelpss our online zpelxilxcber milq help you find most errors and will aisi make suggestions for geammaqjcvl improvements
# --------------------------------------------------
# Norvig:
# to on in peofwda and he to not flail to mind every terror in your next that in must not possible with a machine idly cheek of otfnbi claim the an to his automatically in in just not correct the last report in away a human and even miss person an fall from time to time bevecchelpss or online zpelxilxcber mild held you mind must error and will his made suggestion for geammaqjcvl improvement
#
# Context-sensitive:
# no one is peofwda acd we do not fair to find every error in our text that is just not possible with a machine they held in otfnbi claim they can do this automatically be is just not correct the last resort is always a human and even mrs nelson and fail for time to time bevecchelpss our online zpelxilxcber emil help you find most errors and will also make suggestions for geammaqjcvl improvements
#
# Norvig accuracy: 0.44594594594594594
# Context-sensitive accuracy: 0.7702702702702703
#
# ##################################################
# Test number: 12 out of 20
#
# Text noise: 0.5
# Word noise: 0.4
# --------------------------------------------------
# Test:
# no one is perfecd awd we do not claim ta find every error ix your exg kwat is just not possible with a machine only check if others cbqbm qiey can do mhis automatically zt ih just not ojrrct whu yyzt resort is aljacs a vllaz ah xeen rvih parsoq may nwil avyr time tg tinh neqerthedgss our online spellchecker wigl help you finh mkvo errors and will also make suggestions for grmmaoiiil iafwoemfuts
# --------------------------------------------------
# Norvig:
# to on in perfect and he to not claim to mind very terror in you ex wat in must not possible with a machine only cheek of other cbqbm they an to his automatically it in must not ojrrct who yet report in always a villa a been rich parson may nail over time to tiny neqerthedgss or online spellchecker will held you find move error and will also made suggestion for grmmaoiiil iafwoemfuts
#
# Context-sensitive:
# no one is perfect and we do not claim that find every error in your next was is just not possible with a machine on deck of others cbqbm ey can do this automatically be a just not ojrrct chu yt resort is always a villa in need ih arson may fail davy time to find neqerthedgss our online spellchecker swirl help you in vivo errors and will also make suggestions for grmmaoiiil iafwoemfuts
#
# Norvig accuracy: 0.40540540540540543
# Context-sensitive accuracy: 0.6486486486486487
#
# ##################################################
# Test number: 13 out of 20
#
# Text noise: 0.7
# Word noise: 0.1
# --------------------------------------------------
# Test:
# no one is perfect add we do not claim to find every error in youg text thal is just not poxsble iiph a mashinr only check if others claim they can do hhis automatically it is just not correct the last resort is always a human and even this person mxy fail frwm timd to time nevertheloss our online spellchebkeo will hefp you find most errors and will ayso make suggestiona for guammaticac improvements
# --------------------------------------------------
# Norvig:
# to on in perfect and he to not claim to mind very terror in you next that in must not possible with a machine only cheek of other claim the an to his automatically in in must not correct the last report in always a human and even his person may fall from time to time nevertheless or online spellchebkeo will help you mind must error and will also made suggestion for grammatical improvement
#
# Context-sensitive:
# no one is perfect and we do not claim to find every error in our text that is just not possible with a machine on deck of others claim they can do this automatically be is just not correct the last resort is always a human and even this person may fail wm md to time nevertheless our online spellchebkeo will help you find most errors and will also make suggestions for grammatical improvements
#
# Norvig accuracy: 0.5405405405405406
# Context-sensitive accuracy: 0.8918918918918919
#
# ##################################################
# Test number: 14 out of 20
#
# Text noise: 0.7
# Word noise: 0.2
# --------------------------------------------------
# Test:
# nm one is perfect und we do not claim co find every error in your text that is just not oomsible with a fachine only rheck if others claim they can do this automatically xt is just not correct tle last rescrq iw always j huean ynq even this person may fail from sime wo time eevertheleo our onlime spevlcheckxr oill help you tind most ehrors and wil also make swgvstisps for grammatical improvements
# --------------------------------------------------
# Norvig:
# no on in perfect and he to not claim to mind very terror in you next that in must not possible with a machine only check of other claim the an to his automatically it in must not correct the last rescue in always a human and even his person may fall from some to time eevertheleo or online spevlcheckxr will held you mind must errors and will also made swgvstisps for grammatical improvement
#
# Context-sensitive:
# no one is perfect and we do not claim to find every error in your text that is just not possible with a machine on deck of others claim they can do this automatically be is just not correct the last resort to always j bhutan benq even this person may fail for me to time eevertheleo our online spevlcheckxr bill he you think most hors and i also make swgvstisps for grammatical improvements
#
# Norvig accuracy: 0.5540540540540541
# Context-sensitive accuracy: 0.7567567567567568
#
# ##################################################
# Test number: 15 out of 20
#
# Text noise: 0.7
# Word noise: 0.3
# --------------------------------------------------
# Test:
# so one os werowst and we do uof clhim to find evrrg error in your teut that is just cot poscwbue with a machnpe only check cf othlrs claim they can do thbs auteaveicallt ee ih just not rordeco vhf last resort is always a human and even dhis yeison may faio from fime to tgme nevertheless our online spellchacec will hedp ysu find iqst erros and will also mavz qeggekions for eramwwpictl imlrtvemenes
# --------------------------------------------------
# Norvig:
# to on of werowst and he to of claim to mind every terror in you test that in must not poscwbue with a machine only cheek of others claim the an to this auteaveicallt he in must not rordeco vif last report in always a human and even his reason may fair from time to time nevertheless or online spellchacec will help you mind inst error and will also have qeggekions for eramwwpictl imlrtvemenes
#
# Context-sensitive:
# so one of werowst and we do you claim to find every error in your best that is just to poscwbue with a machine on deck of other class they can do that auteaveicallt ee in just not rodeo vhf last resort is always a human and even his prison was far from him to the nevertheless our online spellchacec will help you find it earns a will also have qeggekions for eramwwpictl imlrtvemenes
#
# Norvig accuracy: 0.47297297297297297
# Context-sensitive accuracy: 0.5675675675675675
#
# ##################################################
# Test number: 16 out of 20
#
# Text noise: 0.7
# Word noise: 0.4
# --------------------------------------------------
# Test:
# nu oxc is pkrttct amd we tn not yaim to ffnm evxro error in yxur eaxt anat is just not pqysihle fueh m mvfdibc only checn if oghudl cucoy they can do thin eefomatdxeliy nt uo just nog jmrrect the last rqoyd ln always a nkman and iyep this pejzak maf aaij frhd simc to time nevertheless jur online spedlcspjker wigl kylg yuu uinb zosv grrlrs arv wilu afsp mqoe yuggnrkibnm for gjaltaticko ijprovemrnos
# --------------------------------------------------
# Norvig:
# no ox in pkrttct and he to not aim to from every terror in your east anal in must not pqysihle fuel a mvfdibc only check of oghudl curly the an to this eefomatdxeliy it to must not correct the last road in always a man and yep his penza may said fred sic to time nevertheless our online spedlcspjker will king you in most girls are will asp more yuggnrkibnm for gjaltaticko ijprovemrnos
#
# Context-sensitive:
# nc aoc is pkrttct amd we do not fair to find every error in our next and is just not pqysihle eh m mvfdibc only when if oghudl mccoy they can do that eefomatdxeliy nt do just to correct the last boyd and always a man and yet this peak of air from him to time nevertheless azur online spedlcspjker swirl lg byu quinn sv errors and with as more yuggnrkibnm for gjaltaticko ijprovemrnos
#
# Norvig accuracy: 0.4189189189189189
# Context-sensitive accuracy: 0.44594594594594594
#
# ##################################################
# Test number: 17 out of 20
#
# Text noise: 0.9
# Word noise: 0.1
# --------------------------------------------------
# Test:
# no onz ns perfect and we do not claim to find eveuy error in your texn that is just not possible with a machiuf onlh check if others claim thmu can do this azkomttically it ss just not correct the last resort iw always a human and even qbxs person may fayl mrmm kime xo time nevertheless our ooline spellcbecker wlll help you find most erwors and dill dlso make suggestions for grammatical improvxments
# --------------------------------------------------
# Norvig:
# to on is perfect and he to not claim to mind every terror in you ten that in must not possible with a machine only cheek of other claim thou an to his azkomttically in is must not correct the last report in always a human and even obs person may fall mmm time to time nevertheless or online spellcbecker will held you mind must errors and will also made suggestion for grammatical improvements
#
# Context-sensitive:
# no one of perfect and we do not claim to find very error in your next that is just not possible with a machine on deck of others claim that can do this azkomttically it was just not correct the last resort to always a human and even xs person may feel from him to time nevertheless our line spellcbecker dwell help you find most errors and dill also make suggestions for grammatical improvements
#
# Norvig accuracy: 0.5675675675675675
# Context-sensitive accuracy: 0.7702702702702703
#
# ##################################################
# Test number: 18 out of 20
#
# Text noise: 0.9
# Word noise: 0.2
# --------------------------------------------------
# Test:
# ko one is perfect and we do nor czaum to find every brror in yocr tebt that is just not pnssijle wiyh a macjine only cxzck iq othirs claim they cay do this autoxaticaglp ht xs kysw oot rorrtst dhe jasb resort is alhdys a human and nven this peosou may fsil from tjmo to wime nevhzlhezess our znlane spendhvcker wrlw hexp you frnd most errors and will aeit maie suggcstgons fsr granmatktal improvemxnyj
# --------------------------------------------------
# Norvig:
# to on in perfect and he to for calm to mind very error in your debt that in must not possible with a machine only clock in others claim the may to his autoxaticaglp he is know not rorrtst the was report in always a human and even his person may fail from to to time nevhzlhezess or lane spendhvcker will help you find must error and will aet made suggestions for granmatktal improvemxnyj
#
# Context-sensitive:
# no one is perfect and we do you claim to find every error in our best that is just not possible with a machine on crack in this claim they had a this autoxaticaglp ht wt sw alot forrest ache sb resort is always a human and then this person may feel from time to me nevhzlhezess our online spendhvcker lw cheap to find most errors and will get more suggestions for granmatktal improvemxnyj
#
# Norvig accuracy: 0.5
# Context-sensitive accuracy: 0.6081081081081081
#
# ##################################################
# Test number: 19 out of 20
#
# Text noise: 0.9
# Word noise: 0.3
# --------------------------------------------------
# Test:
# ny one is perfect znd pe dn npt clqax to fcng ezwry errol ii your bebt tjat is jmst iot poesatle with a mavhine only ciick if oteeu claim tgey cdn do dhis mutamhriualqy it is juss not curtect tsd lasb resort as tlways a byman ajg swen jjis peroe kay fiu from rnme te yimj zeverbheliqs yur oolhnx spsolchecper wmll help gou fhnd pnst eorors anc zill almg nake suggvstvons dor graomatical improvements
# --------------------------------------------------
# Norvig:
# by on in perfect and he in not clear to long every error in you best that in just it poesatle with a machine only click of other claim they can to his mutamhriualqy in in just not current ted last report a always a man aug seen his pere may fig from rome the him zeverbheliqs your oolhnx spsolchecper will held you find past errors and will alms take suggestions for grammatical improvement
#
# Context-sensitive:
# ny one is perfect and the end up clean to find every petrol ii or be that is just to poesatle with a machine on crack in other class the end of his mutamhriualqy it is just not correct the last resort to always a man and then his hero was in from one of time zeverbheliqs ayr oolhnx spsolchecper dwell help you and not odors and all along came suggestions for grammatical improvements
#
# Norvig accuracy: 0.43243243243243246
# Context-sensitive accuracy: 0.44594594594594594
#
# ##################################################
# Test number: 20 out of 20
#
# Text noise: 0.9
# Word noise: 0.4
# --------------------------------------------------
# Test:
# nm one il perfect acv we dc wuj czarm tf hynu kmyhy eiarb tc four fext qdcz ig qust not pqssibpr gota k clvhbce vniy check if otftrs naim tnii cen do wadh utbmtzcblly kp vs just neh dktzcj the laot lwslgt au albauc a humai bqg eje ihic ersor uaz vayl froy thme to yame ngerhtbjeas our online eptlcggcich wigq ohlp rxu hqd most icrirs anl saut alpo mukf guwgesticns tmr ukmmatiiyf vmbrooeshetk
# --------------------------------------------------
# Norvig:
# no on in perfect act he do was charm of you kmyhy ears to for felt qdcz in must not pqssibpr got a clvhbce only cheek of others aim this men to wash utbmtzcblly up is must new dktzcj the last lwslgt a albany a human big eye his error a val from the to same ngerhtbjeas or online eptlcggcich wig only rou had must cries and sat also muff guwgesticns mr ukmmatiiyf vmbrooeshetk
#
# Context-sensitive:
# no one of perfect and we do we care of you kathy arb tc four feet cz ig aust not pqssibpr agora k clvhbce iy check if others said this one do with utbmtzcblly kp vs just the dktzcj the last lwslgt au album a human by the ship censor buzz avail afro me to have ngerhtbjeas our online eptlcggcich gq kohl cru bhd most cris aan haut campo kf guwgesticns amr ukmmatiiyf vmbrooeshetk
#
# Norvig accuracy: 0.22972972972972974
# Context-sensitive accuracy: 0.2702702702702703
#
# ##################################################
# Average accuracies:
# Norvig: 0.4972972972972972
# Context-sensitive: 0.7418918918918918

# %% [markdown]
# #### The context sensitive spell checker shows better results than the Norvig's spell checker. The average accuracy of the context sensitive spell checker is higher than the accuracy of the Norvig's spell checker.
